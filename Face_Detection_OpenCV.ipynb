# %% [markdown]
# <a href="https://colab.research.google.com/github/LeoMajorR/TensorFlow/blob/main/Face_Detection_OpenCV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install opencv-python
import cv2
from google.colab import files
from io import BytesIO
from PIL import Image
from google.colab.patches import cv2_imshow
from matplotlib import pyplot as plt
# Out:
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.6/dist-packages (4.1.2.30)
# Requirement already satisfied: numpy>=1.11.3 in /usr/local/lib/python3.6/dist-packages (from opencv-python) (1.18.5)

# %%
#Load the Cascade
face_cascade = cv2.CascadeClassifier("haarcascade_frontalface_default.xml")

#Read Input Image
#uploaded = files.upload()
#img = cv2.imread(Image.open(BytesIO(uploaded['Image_file_name.jpg'])))
#img=cv2.imread("index.jpg")
uploaded = files.upload()

for fn in uploaded.keys():

    # predicting images
    path = '/content/' + fn
    img = image.load_img(path)

    #convert to grayscale
    gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

    #Detect faces
    faces=face_cascade.detectMultiScale(gray,1.1,4)

    #draw rectangle around the faces
    for (x,y,w,h) in faces:
        cv2.rectangle(img, (x, y), (x+w, y+h), (255, 0, 0), 2)

    #Display the output
    cv2_imshow(img)
    cv2.waitKey()
# Out:
#      <input type="file" id="files-c6d62fb8-91b0-4827-ad7e-92edfa87503a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c6d62fb8-91b0-4827-ad7e-92edfa87503a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>

# %%
# Load the cascade
face_cascade = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

# Read the input image
img = cv2.imread('index.jpg')

# Convert into grayscale
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# Detect faces
faces = face_cascade.detectMultiScale(gray, 1.1, 4)

# Draw rectangle around the faces
for (x, y, w, h) in faces:
    cv2.rectangle(img, (x, y), (x+w, y+h), (255, 0, 0), 2)

# Display the output
cv2_imshow(img)
cv2.waitKey()
# Out:
# <PIL.Image.Image image mode=RGB size=277x182 at 0x7F8FCEEB1860>
# -1
