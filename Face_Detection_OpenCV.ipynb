# %% [markdown]
# <a href="https://colab.research.google.com/github/LeoMajorR/TensorFlow/blob/main/Face_Detection_OpenCV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Face Detection using OpenCV

# %%
# !pip install opencv-python
import cv2
from google.colab import files
from google.colab.patches import cv2_imshow

# %%
# %time

#Load the Cascade
face_cascade = cv2.CascadeClassifier("haarcascade_frontalface_default.xml")

#Read Input Image
uploaded = files.upload()

for fn in uploaded.keys():

    # predicting images
    path = '/content/' + fn
    img = cv2.imread(path)

    #convert to grayscale
    gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

    #Detect faces
    faces=face_cascade.detectMultiScale(gray,1.1,4)

    #draw rectangle around the faces
    for (x,y,w,h) in faces:
        cv2.rectangle(img, (x, y), (x+w, y+h), (255, 0, 0), 2)

    #Display the output
    cv2_imshow(img)
    cv2.waitKey()
# Out:
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 4.53 µs
#      <input type="file" id="files-ee3ab184-9221-4a70-9c51-0bc373358ffa" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ee3ab184-9221-4a70-9c51-0bc373358ffa">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving f1.jpeg to f1 (1).jpeg
# <PIL.Image.Image image mode=RGB size=300x168 at 0x7F8F9C4084A8>

# %%
# %time
# Load the cascade
face_cascade = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')

#!wget "https://github.com/intel-iot-devkit/sample-videos/raw/master/classroom.mp4"

# To capture video from webcam. 
#cap = cv2.VideoCapture(0)
# To use a video file as input 
cap = cv2.VideoCapture('classroom.mp4')

while True:
    # Read the frame
    _, img = cap.read()
    # Convert to grayscale
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    # Detect the faces
    faces = face_cascade.detectMultiScale(gray, 1.1, 4)
    # Draw the rectangle around each face
    for (x, y, w, h) in faces:
        cv2.rectangle(img, (x, y), (x+w, y+h), (255, 0, 0), 2)
    # Display
    cv2_imshow(img)
    # Stop if escape key is pressed
    k = cv2.waitKey(30) & 0xff
    if k==27:
        break
# Release the VideoCapture object
cap.release()
